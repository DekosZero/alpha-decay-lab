# %% [markdown]
# # Notebook: 05_adaptive_weights
#
# **TODO:** Stub notebook. Run 01_data_pipeline first.
#
# See README.md phase descriptions for what to build here.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import sys
sys.path.insert(0, str(Path("..")))

from halflife import SignalDecayEstimator
from halflife.features import OrderFlowImbalance, TradeSigns, ShortTermReversal
from halflife.utils import forward_returns, winsorise

DATA_PROC = Path("../data/processed")
